# %% [markdown]
# # Semana Imersão_Dados - Alura
#
#
# *   Feito por: Geovanna da S. Lima
# *   GitHub: https://github.com/Geovanna-Lima
# *   LinkedIn: www.linkedin.com/in/geovanna-s-lima

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc = 'mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
sns.scatterplot(x = 'g-0', y = 'g-3', data = dados)

plt.show()

# %%
sns.lmplot(data = dados, x= 'g-0', y = 'g-3', line_kws = {'color': 'red'})

plt.show()

# %%
dados[['g-0', 'g-8']]
# Out:
#           g-0     g-8
# 0      1.0620  0.5548
# 1      0.0743 -0.4047
# 2      0.6280  0.0065
# 3     -0.5138 -0.1321
# 4     -0.3254 -0.8789
# ...       ...     ...
# 23809  0.1394 -0.4726
# 23810 -1.3260  0.5112
# 23811  0.3942 -0.0340
# 23812  0.6660  0.4299
# 23813 -0.8598  3.0790
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x = 'g-0', y = 'g-8', data = dados)

plt.show()

# %%
sns.lmplot(data = dados, x= 'g-0', y = 'g-8', line_kws = {'color': 'red'})

plt.show()

# %%
sns.lmplot(data = dados, x= 'g-0', y = 'g-8', line_kws = {'color': 'red'}, col = 'tratamento', row = 'tempo')

plt.show()

# %%
dados.loc[:, 'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = dados.loc[:, 'g-0':'g-50'].corr()

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %%
corr_celular = dados.loc[:, 'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# #Desafios
#
# ###Desafio 01: Criar tabelas de frequência com pandas.groupby()
#
# ###Desafio 02: Normalizar o crosstab pela coluna.
#
# ###Desafio 03: Explorar outros agregadores.
#
# ###Desafio 04: Explorar o melt.
#
# ###Desafio 05: Calcular e atualizar a correlação entre o G e C. Reflefir sobre os efeitos biológicos.
#
# ###Desafio 06: Estudar o código que plota a matriz de correlação (heatmap).
#
# ###Desafio 07: Resumo do que aprendeu na aula.

# %% [markdown]
# <h1> Resolução dos Desafios</h1>

# %% [markdown]
# ###Desafio 01:

# %%
desafio_um = dados.groupby(['dose', 'tempo']).size().unstack(1)
desafio_um.head()
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %% [markdown]
# ###Desafio 02

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ###Desafio 03:

# %% [markdown]
# <p>Podemos usar outros agregadores como o de média, maximo, mínimo, desvio padrão, soma, etc.</p>

# %%
desafio_tres = pd.DataFrame(dados) 
desafio_tres [['dose', 'tempo', 'tratamento']].groupby(['dose', 'tratamento']).sum()
# Out:
#                     tempo
# dose tratamento
# D1   com_controle   45792
#      com_droga     537768
# D2   com_controle   43920
#      com_droga     516072

# %% [markdown]
# ###Desafio 04:

# %% [markdown]
# <p>Com o método melt() é possivel sudar a apresentação da tabela, rotacionando as colunas e linhas.</p>
#
# https://pandas.pydata.org/docs/reference/api/pandas.melt.html

# %%
pd.melt(dados, id_vars=['dose','tempo','tratamento'], value_vars=['g-0'])
# Out:
#       dose  tempo    tratamento variable   value
# 0       D1     24     com_droga      g-0  1.0620
# 1       D1     72     com_droga      g-0  0.0743
# 2       D1     48     com_droga      g-0  0.6280
# 3       D1     48     com_droga      g-0 -0.5138
# 4       D2     72     com_droga      g-0 -0.3254
# ...    ...    ...           ...      ...     ...
# 23809   D2     24     com_droga      g-0  0.1394
# 23810   D2     24     com_droga      g-0 -1.3260
# 23811   D2     48  com_controle      g-0  0.3942
# 23812   D1     24     com_droga      g-0  0.6660
# 23813   D1     72     com_droga      g-0 -0.8598
#
# [23814 rows x 5 columns]

# %% [markdown]
# ###Desafio 05:

# %%
g = dados[dados['tratamento'] == 'com_droga'].loc[:,'g-0':'g-50']
c = dados[dados['tratamento'] == 'com_droga'].loc[:,'c-0':'c-50']

tb = pd.concat([g,c], axis = 1)
tb
# Out:
#           g-0     g-1     g-2     g-3  ...    c-47    c-48    c-49    c-50
# 0      1.0620  0.5577 -0.2479 -0.6208  ...  1.3070 -1.0230  0.7709  0.7180
# 1      0.0743  0.4087  0.2991  0.0604  ...  0.6065  0.6259  0.4716  0.0453
# 2      0.6280  0.5817  1.5540 -0.0764  ...  0.1787  0.3354  0.1349 -0.3569
# 3     -0.5138 -0.2491 -0.2656  0.5288  ... -1.3390 -3.0160 -3.0040 -2.8880
# 4     -0.3254 -0.4009  0.9700  0.6919  ... -0.2353 -0.1285 -0.1740  0.3559
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23808  0.1608 -1.0500  0.2551 -0.2239  ...  0.3631 -0.0474 -0.6761  0.6650
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ... -0.6097  0.7577  0.0365  0.1181
# 23810 -1.3260  0.3478 -0.3743  0.9905  ... -0.7309  0.2137 -0.1295 -0.1987
# 23812  0.6660  0.2324  0.4392  0.2044  ...  0.5460 -0.7703 -0.1128  0.9409
# 23813 -0.8598  1.0240 -0.1361  0.7952  ... -0.7138 -1.6730 -1.4890 -6.0290
#
# [21948 rows x 102 columns]

# %%
corr_gc = tb.corr()
corr_gc
# Out:
#            g-0       g-1       g-2  ...      c-48      c-49      c-50
# g-0   1.000000  0.071546  0.176710  ... -0.603942 -0.617839 -0.604046
# g-1   0.071546  1.000000 -0.050010  ...  0.003686  0.035052  0.024609
# g-2   0.176710 -0.050010  1.000000  ... -0.163114 -0.171502 -0.157127
# g-3   0.023815 -0.011016  0.040901  ... -0.062495 -0.036906 -0.014167
# g-4   0.410954  0.164478  0.025538  ... -0.360632 -0.362597 -0.373212
# ...        ...       ...       ...  ...       ...       ...       ...
# c-46 -0.610167 -0.007487 -0.170008  ...  0.823017  0.820953  0.828521
# c-47 -0.660685  0.009141 -0.177350  ...  0.853127  0.854897  0.849757
# c-48 -0.603942  0.003686 -0.163114  ...  1.000000  0.856524  0.868251
# c-49 -0.617839  0.035052 -0.171502  ...  0.856524  1.000000  0.862033
# c-50 -0.604046  0.024609 -0.157127  ...  0.868251  0.862033  1.000000
#
# [102 rows x 102 columns]

# %%
corr_filtrada = corr_gc.loc[:'g-50','c-0':]
corr_filtrada.shape
# Out:
# (51, 51)

# %%
# Generate a mask for the upper triangle
#mask = np.triu(np.ones_like(corr_filtrada, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_filtrada, cmap=cmap, center=0, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# ####Reflefir sobre os efeitos biológicos:
# <p>Podemos perceber que nos pontos mais vermelhos temos uma maior correlação. Vemos então uma alta relação/viabilidade do gene com a célula, ambos os valores vão para a mesma direção.</p>
# <p>Já nos pontos mais azuis temos uma baixa correlação. Isso faz com que os seus valores mudem em direções opostas. Porém apenas com esse gráfico não podemos dizer se temos diminuição da viabilidade do gene com a célula e da célula com o gene, esse fator só é possível de ser visto no "lmpot()".</p>
# <p>O gráfico acima nos ajuda a ver os genes que podem ganhar uma atenção maior.</p>
# <p>Também podemos notar que muitos genes não tem uma grande correlação com a célula, podemos pensar que esses genes não estão envolvidos diretamente com as vias metabólicas das células escolhidas e não irão reagir da melhor maneira com o composto, então podemos pensar em descartar esses genes nos próximos testes.</p>

# %% [markdown]
# ###Desafio 06:

# %%
#Nessa parte criamos a corelação entre os genes, podendo filtrar a matrix  
corr = dados.loc[:, 'g-0':'g-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
#Aqui a mask é um triangulo superior (np.triu) de um array das mesmas dimensões que nossa matrix de correlação e seus valores são do tipo booleano e iguais a 1.

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
#Aqui a área de plotagem está sendo criada

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
#Aqui uma paleta de cosres estaá sendo selecionada para ser usado no heatmap

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
#Aqui o heatmap é criado e podemos visualisar suas correlações

plt.show()

# %% [markdown]
# ###Desafio 07:

# %% [markdown]
# <h5>Nessa aula aprendi:</h5>
#
# *   Como utilizar e relacionar o "crosstab()" a partir dos dados categóricos;
# *   Como utilizar o "scatterplot()";
# *   Vimos correlações e como utilizar o "lmplot()" criando uma curva de análise;
# *   O que é correlação e como calcular essa correlação;
# *   O que é um Plotting diagram e como analisar;
