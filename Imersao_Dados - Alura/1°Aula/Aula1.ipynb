# %% [markdown]
# # Semana Imersão_Dados - Alura
#
#
# *   Feito por: Geovanna da S. Lima
# *   GitHub: https://github.com/Geovanna-Lima
# *   LinkedIn: www.linkedin.com/in/geovanna-s-lima

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['dose'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# <h1>Desafios</h1>

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# ###Desafio 02: Plotar as 5 últimas linhas da tabela
#
# ###Desafio 03: Proporção das classes tratamento
#
# ###Desafio 04: Quantos tipos de Drogas foram investigadas?
#
# ###Desafio 05: Procurar na documentação o método query (pandas)
#
# ###Desafio 06: Renomear as colunas tirando o Hífen
#
# ###Desafio 07: Melhorar os gráficos
#
# ###Desafio 08: Resumo do que aprendeu na aula

# %% [markdown]
# <h1> Resolução dos Desafios</h1>

# %% [markdown]
# ###Desafio 01:

# %%
controle = dados.query('tratamento == "com_controle"')
controle.droga.unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %% [markdown]
# <p>Podemos perceber que em todos os dados "com_controle" temos a coluna 'cacb2b860', podendo indicar a ausencia da mesma, então podemos entender que temos menos experimentos dela, já que o que está variando são os outros fatores.</p>

# %% [markdown]
# ###Desafio 02:

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03:

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# ###Desafio 04:

# %%
print(f'Foram investigadas {len(dados["droga"].unique())} tipos de drogas')
# Out:
# Foram investigadas 3289 tipos de drogas

# %% [markdown]
# ###Desafio 05:

# %% [markdown]
# Link do site: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %% [markdown]
# ###Desafio 06:

# %%
#dados = dados.rename(columns={'g-0': "g0"}) em todas as células
#ou

# %%
dados.columns = dados.columns.str.replace("[-]", "")
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 07:

# %%
dados['dose'].value_counts().plot(title = 'Quantidade de Doses', kind = 'pie', autopct='%0.2f%%', label = 'D1 e D2 em %')

# %%
import matplotlib.pyplot as plt

#dados['tempo'].value_counts().plot.bar(color=['pink', 'aqua', 'silver'])

fig = plt.figure()

ax = fig.add_axes([0,0,1,2])

plt.title('Tempo de Teste', fontweight='bold', fontsize='15') 
plt.xlabel('Qnt de Horas', fontweight='light', fontsize='14')
plt.ylabel('Células que Reagiram', fontweight='light', fontsize='14')


dados_temp = dados['tempo'].value_counts()

a = dados_temp.loc[48]
b = dados_temp.loc[72]
c = dados_temp.loc[24]

ax.bar("48hrs", a, label="Reação em 48 Hrs", color="pink")
ax.bar("72hrs", b, label="Reação em 72 Hrs", color="aqua") 
ax.bar("24hrs", c, label="Reação em 24 Hrs", color="silver") 

plt.legend()

# %% [markdown]
# ###Desafio 08:

# %% [markdown]
# <h5>Nessa aula aprendi:</h5>
#
#
# *   Como importar uma base de dados usando o Pandas;
# *   Usar alguns comandos como:
#     *   unique();
#     *   head();
#     *   tail();
#     *   count();
#     *   value_counts();
#     *   shape.
# *  Usar o "normalize=True" para saber a proporção;
# *  Usar os comandos ".plot.bar()" e ".plot.pie()";
# *  E percebi que existem gráficos para cada momento.
